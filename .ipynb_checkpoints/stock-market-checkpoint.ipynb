# %%
import pandas as pd
import numpy as np

print("Setup working")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[41], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 import scikit_learn as sklearn
#       4
#       5 print("Setup working")
#
# ModuleNotFoundError: No module named 'scikit_learn'

# %%
import yfinance as yf

# %%
nifty_stocks = [
    "RELIANCE.NS",
    "TCS.NS",
    "INFY.NS",
    "HDFCBANK.NS",
    "ICICIBANK.NS"
]

# %%
data = yf.download(
    nifty_stocks,
    start="2023-01-01",
    end="2025-01-01"
)
# Out:
# [*********************100%***********************]  5 of 5 completed

# %%
data.head()
# Out:
# Price            Close                                                      \
# Ticker     HDFCBANK.NS ICICIBANK.NS      INFY.NS  RELIANCE.NS       TCS.NS
# Date
# 2023-01-02  783.677917   880.647339  1397.702148  1175.889648  2932.793945
# 2023-01-03  788.802368   879.573914  1396.372437  1167.284668  2977.665527
# 2023-01-04  774.704163   877.378235  1370.921997  1149.709595  2980.632568
# 2023-01-05  769.723999   857.910278  1352.946167  1147.655273  2977.440674
# 2023-01-06  767.173889   849.078857  1328.458984  1158.086304  2887.922607
#
# Price             High                                                      \
# Ticker     HDFCBANK.NS ICICIBANK.NS      INFY.NS  RELIANCE.NS       TCS.NS
# Date
# 2023-01-02  788.994845   885.087402  1399.994967  1177.304802  2937.649920
# 2023-01-03  790.558642   884.062816  1405.635401  1174.565828  2985.443779
# 2023-01-04  791.881828   885.965680  1394.950689  1169.110728  2992.052965
# 2023-01-05  778.553474   881.184053  1381.102043  1157.858026  3001.000457
# 2023-01-06  774.247032   857.715082  1352.762859  1163.130627  2968.853320
#
# Price       ...        Open                                         \
# Ticker      ... HDFCBANK.NS ICICIBANK.NS      INFY.NS  RELIANCE.NS
# Date        ...
# 2023-01-02  ...  782.859956   872.401474  1388.530874  1164.066352
# 2023-01-03  ...  780.550329   876.792792  1393.896125  1170.936659
# 2023-01-04  ...  786.709275   877.280675  1394.950689  1167.261851
# 2023-01-05  ...  777.085889   879.134811  1381.102043  1151.969199
# 2023-01-06  ...  770.830752   857.715082  1348.177223  1153.407240
#
# Price                        Volume
# Ticker           TCS.NS HDFCBANK.NS ICICIBANK.NS  INFY.NS RELIANCE.NS   TCS.NS
# Date
# 2023-01-02  2932.389336     4381378      4315403  3801140     5316175   709547
# 2023-01-03  2924.296136     8378030      5846855  4551130     7658932  1245178
# 2023-01-04  2973.483734    10351600     12454582  7059590     9264891  1231668
# 2023-01-05  2994.615836    10941436     16547196  9868404    13637099  1826057
# 2023-01-06  2967.459470     9092462     14804613  6443714     6349597  2488376
#
# [5 rows x 25 columns]

# %%
data.columns
# Out:
# MultiIndex([( 'Close',  'HDFCBANK.NS'),
#             ( 'Close', 'ICICIBANK.NS'),
#             ( 'Close',      'INFY.NS'),
#             ( 'Close',  'RELIANCE.NS'),
#             ( 'Close',       'TCS.NS'),
#             (  'High',  'HDFCBANK.NS'),
#             (  'High', 'ICICIBANK.NS'),
#             (  'High',      'INFY.NS'),
#             (  'High',  'RELIANCE.NS'),
#             (  'High',       'TCS.NS'),
#             (   'Low',  'HDFCBANK.NS'),
#             (   'Low', 'ICICIBANK.NS'),
#             (   'Low',      'INFY.NS'),
#             (   'Low',  'RELIANCE.NS'),
#             (   'Low',       'TCS.NS'),
#             (  'Open',  'HDFCBANK.NS'),
#             (  'Open', 'ICICIBANK.NS'),
#             (  'Open',      'INFY.NS'),
#             (  'Open',  'RELIANCE.NS'),
#             (  'Open',       'TCS.NS'),
#             ('Volume',  'HDFCBANK.NS'),
#             ('Volume', 'ICICIBANK.NS'),
#             ('Volume',      'INFY.NS'),
#             ('Volume',  'RELIANCE.NS'),
#             ('Volume',       'TCS.NS')],
#            names=['Price', 'Ticker'])

# %%
close_prices = data['Close']
close_prices.head()
# Out:
# Ticker      HDFCBANK.NS  ICICIBANK.NS      INFY.NS  RELIANCE.NS       TCS.NS
# Date
# 2023-01-02   783.677917    880.647339  1397.702148  1175.889648  2932.793945
# 2023-01-03   788.802368    879.573914  1396.372437  1167.284668  2977.665527
# 2023-01-04   774.704163    877.378235  1370.921997  1149.709595  2980.632568
# 2023-01-05   769.723999    857.910278  1352.946167  1147.655273  2977.440674
# 2023-01-06   767.173889    849.078857  1328.458984  1158.086304  2887.922607

# %%
close_prices.to_csv("data/nifty_close_prices.csv")

# %%
import os

os.makedirs("data", exist_ok=True)

# %%
import pandas as pd

close_prices = pd.read_csv(
    "data/nifty_close_prices.csv",
    index_col=0,
    parse_dates=True
)

close_prices.head()
# Out:
#             HDFCBANK.NS  ICICIBANK.NS      INFY.NS  RELIANCE.NS       TCS.NS
# Date
# 2023-01-02   783.677917    880.647339  1397.702148  1175.889648  2932.793945
# 2023-01-03   788.802368    879.573914  1396.372437  1167.284668  2977.665527
# 2023-01-04   774.704163    877.378235  1370.921997  1149.709595  2980.632568
# 2023-01-05   769.723999    857.910278  1352.946167  1147.655273  2977.440674
# 2023-01-06   767.173889    849.078857  1328.458984  1158.086304  2887.922607

# %%
import matplotlib.pyplot as plt

close_prices.plot(figsize=(14,7))
plt.title("Raw Closing Prices")
plt.xlabel("Date")
plt.ylabel("Price")
plt.show()

# %%
normalized = close_prices / close_prices.iloc[0] * 100
normalized.head()
# Out:
#             HDFCBANK.NS  ICICIBANK.NS     INFY.NS  RELIANCE.NS      TCS.NS
# Date
# 2023-01-02   100.000000    100.000000  100.000000   100.000000  100.000000
# 2023-01-03   100.653898     99.878110   99.904864    99.268215  101.529994
# 2023-01-04    98.854918     99.628784   98.083987    97.773596  101.631162
# 2023-01-05    98.219432     97.418142   96.797888    97.598892  101.522327
# 2023-01-06    97.894029     96.415310   95.045928    98.485968   98.470014

# %%
normalized.plot(figsize=(14,7))
plt.title("Raw Closing Prices")
plt.xlabel("Date")
plt.ylabel("Price")
plt.show()

# %%
daily_returns = close_prices.pct_change()
daily_returns.head()
# Out:
#             HDFCBANK.NS  ICICIBANK.NS   INFY.NS  RELIANCE.NS    TCS.NS
# Date
# 2023-01-02          NaN           NaN       NaN          NaN       NaN
# 2023-01-03     0.006539     -0.001219 -0.000951    -0.007318  0.015300
# 2023-01-04    -0.017873     -0.002496 -0.018226    -0.015056  0.000996
# 2023-01-05    -0.006428     -0.022189 -0.013112    -0.001787 -0.001071
# 2023-01-06    -0.003313     -0.010294 -0.018099     0.009089 -0.030065

# %%
volatility = daily_returns.std()
volatility.sort_values()
# Out:
# ICICIBANK.NS    0.011551
# TCS.NS          0.012417
# HDFCBANK.NS     0.012472
# RELIANCE.NS     0.012813
# INFY.NS         0.014542
# dtype: float64

# %%
avg_return = daily_returns.mean()
avg_return.sort_values(ascending=False)
# Out:
# ICICIBANK.NS    0.000817
# INFY.NS         0.000652
# TCS.NS          0.000651
# HDFCBANK.NS     0.000302
# RELIANCE.NS     0.000141
# dtype: float64

# %%
volatility.sort_values().plot(kind='bar', color='pinK', figsize=(10,5))
plt.title("Stock Volatility Comparison")
plt.ylabel("Volatility")
plt.show()

# %%
risk_adjusted = avg_return / volatility
risk_adjusted.sort_values(ascending=False)
# Out:
# ICICIBANK.NS    0.070737
# TCS.NS          0.052448
# INFY.NS         0.044808
# HDFCBANK.NS     0.024245
# RELIANCE.NS     0.011023
# dtype: float64

# %%
risk_adjusted.sort_values().plot(kind='bar', figsize=(10,5))
plt.title("Risk Adjusted Performance")
plt.ylabel("Score")
plt.show()

# %%
correlation = daily_returns.corr()
correlation
# Out:
#               HDFCBANK.NS  ICICIBANK.NS   INFY.NS  RELIANCE.NS    TCS.NS
# HDFCBANK.NS      1.000000      0.421591  0.170981     0.337548  0.129923
# ICICIBANK.NS     0.421591      1.000000  0.210505     0.403507  0.186498
# INFY.NS          0.170981      0.210505  1.000000     0.245066  0.687034
# RELIANCE.NS      0.337548      0.403507  0.245066     1.000000  0.248459
# TCS.NS           0.129923      0.186498  0.687034     0.248459  1.000000

# %%
import seaborn as sns
plt.figure(figsize=(8,6))
sns.heatmap(correlation, annot=True)
plt.title("Stock Correlation Heatmap")
plt.show()

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in C:\Users\HP\miniconda3\envs\stock-analysis\Lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in C:\Users\HP\miniconda3\envs\stock-analysis\Lib\site-packages (from seaborn) (2.4.4)
# Requirement already satisfied: pandas>=1.2 in C:\Users\HP\miniconda3\envs\stock-analysis\Lib\site-packages (from seaborn) (3.0.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in C:\Users\HP\miniconda3\envs\stock-analysis\Lib\site-packages (from seaborn) (3.10.9)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\HP\miniconda3\envs\stock-analysis\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\HP\miniconda3\envs\stock-analysis\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\HP\miniconda3\envs\stock-analysis\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\HP\miniconda3\envs\stock-analysis\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in C:\Users\HP\miniconda3\envs\stock-analysis\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.0)
# Requirement already satisfied: pillow>=8 in C:\Users\HP\miniconda3\envs\stock-analysis\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\HP\miniconda3\envs\stock-analysis\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\HP\miniconda3\envs\stock-analysis\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\HP\miniconda3\envs\stock-analysis\Lib\site-packages (from pandas>=1.2->seaborn) (2026.2)
# Requirement already satisfied: six>=1.5 in C:\Users\HP\miniconda3\envs\stock-analysis\Lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)

# %%
icici = close_prices["ICICIBANK.NS"]

# %%
ma_20 = icici.rolling(window=20).mean()
ma_50 = icici.rolling(window=50).mean()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14,7))
plt.plot(icici, label="ICICI Price")
plt.plot(ma_20, label="20-Day MA")
plt.plot(ma_50, label="50-Day MA")

plt.legend()
plt.title("ICICI Moving Average Analysis")
plt.show()

# %%
signals = pd.DataFrame(index=icici.index)
signals['price'] = icici
signals['ma_20'] = ma_20
signals['ma_50'] = ma_50

signals['signal'] = 0
signals.loc[signals['ma_20'] > signals['ma_50'], 'signal'] = 1
signals.loc[signals['ma_20'] < signals['ma_50'], 'signal'] = -1

signals['positions'] = signals['signal'].diff()

# %%
plt.figure(figsize=(14,7))

plt.plot(signals['price'], label='ICICI Price')
plt.plot(signals['ma_20'], label='20-Day MA')
plt.plot(signals['ma_50'], label='50-Day MA')

plt.plot(signals[signals['positions'] == 2].index,
         signals['ma_20'][signals['positions'] == 2],
         '^', markersize=10, label='Buy Signal')

plt.plot(signals[signals['positions'] == -2].index,
         signals['ma_20'][signals['positions'] == -2],
         'v', markersize=10, label='Sell Signal')

plt.legend()
plt.title('ICICI Buy/Sell Signals')
plt.show()

# %%
data['MA20'] = data['Close'].rolling(20).mean()
data['MA50'] = data['Close'].rolling(50).mean()

data['Returns'] = data['Close'].pct_change()

data['Volatility'] = data['Returns'].rolling(20).std()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 data['MA20'] = data['Close'].rolling(20).mean()
#       2 data['MA50'] = data['Close'].rolling(50).mean()
#       3
#       4 data['Returns'] = data['Close'].pct_change()
#
# File ~\miniconda3\envs\stock-analysis\Lib\site-packages\pandas\core\frame.py:4662, in DataFrame.__setitem__(self, key, value)
#    4658             self._setitem_frame(key, value)
#    4659         elif isinstance(key, (Series, np.ndarray, list, Index)):
#    4660             self._setitem_array(key, value)
#    4661         elif isinstance(value, DataFrame):
# -> 4662             self._set_item_frame_value(key, value)
#    4663         elif (
#    4664             is_list_like(value)
#    4665             and not self.columns.is_unique
#
# File ~\miniconda3\envs\stock-analysis\Lib\site-packages\pandas\core\frame.py:4825, in DataFrame._set_item_frame_value(self, key, value)
#    4821
#    4822             return self.isetitem(locs, value)
#    4823
#    4824         if len(value.columns) > 1:
# -> 4825             raise ValueError(
#    4826                 "Cannot set a DataFrame with multiple columns to the single "
#    4827                 f"column {key}"
#    4828             )
#
# ValueError: Cannot set a DataFrame with multiple columns to the single column MA20

# %%
print(data.columns)
# Out:
# MultiIndex([( 'Close',  'HDFCBANK.NS'),
#             ( 'Close', 'ICICIBANK.NS'),
#             ( 'Close',      'INFY.NS'),
#             ( 'Close',  'RELIANCE.NS'),
#             ( 'Close',       'TCS.NS'),
#             (  'High',  'HDFCBANK.NS'),
#             (  'High', 'ICICIBANK.NS'),
#             (  'High',      'INFY.NS'),
#             (  'High',  'RELIANCE.NS'),
#             (  'High',       'TCS.NS'),
#             (   'Low',  'HDFCBANK.NS'),
#             (   'Low', 'ICICIBANK.NS'),
#             (   'Low',      'INFY.NS'),
#             (   'Low',  'RELIANCE.NS'),
#             (   'Low',       'TCS.NS'),
#             (  'Open',  'HDFCBANK.NS'),
#             (  'Open', 'ICICIBANK.NS'),
#             (  'Open',      'INFY.NS'),
#             (  'Open',  'RELIANCE.NS'),
#             (  'Open',       'TCS.NS'),
#             ('Volume',  'HDFCBANK.NS'),
#             ('Volume', 'ICICIBANK.NS'),
#             ('Volume',      'INFY.NS'),
#             ('Volume',  'RELIANCE.NS'),
#             ('Volume',       'TCS.NS')],
#            names=['Price', 'Ticker'])

# %%
icici.head()
# Out:
# Date
# 2023-01-02    880.647339
# 2023-01-03    879.573914
# 2023-01-04    877.378235
# 2023-01-05    857.910278
# 2023-01-06    849.078857
# Name: ICICIBANK.NS, dtype: float64

# %%
icici_df = icici.to_frame(name='Close')

# %%
icici_df['MA20'] = icici_df['Close'].rolling(20).mean()
icici_df['MA50'] = icici_df['Close'].rolling(50).mean()

icici_df['Returns'] = icici_df['Close'].pct_change()
icici_df['Volatility'] = icici_df['Returns'].rolling(20).std()

icici_df['Target'] = icici_df['Close'].shift(-1)

# %%
icici_df.dropna(inplace=True)

# %%
X = icici_df[['MA20', 'MA50', 'Returns', 'Volatility']]
y = icici_df['Target']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,
    shuffle=False
)

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in C:\Users\HP\miniconda3\envs\stock-analysis\Lib\site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.24.1 in C:\Users\HP\miniconda3\envs\stock-analysis\Lib\site-packages (from scikit-learn) (2.4.4)
# Requirement already satisfied: scipy>=1.10.0 in C:\Users\HP\miniconda3\envs\stock-analysis\Lib\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in C:\Users\HP\miniconda3\envs\stock-analysis\Lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in C:\Users\HP\miniconda3\envs\stock-analysis\Lib\site-packages (from scikit-learn) (3.6.0)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
predictions = model.predict(X_test)

# %%
mae = mean_absolute_error(y_test, predictions)
mse = mean_squared_error(y_test, predictions)

print("MAE:", mae)
print("MSE:", mse)
# Out:
# MAE: 34.797045314417474
# MSE: 1671.4632376509662

# %%
plt.figure(figsize=(14,7))

plt.plot(y_test.values, label='Actual Price')
plt.plot(predictions, label='Predicted Price')

plt.legend()
plt.title('Actual vs Predicted ICICI Stock Price')
plt.show()

# %%
from sklearn.ensemble import RandomForestRegressor

rf_model = RandomForestRegressor(
    n_estimators=100,
    random_state=42
)

rf_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
rf_predictions = rf_model.predict(X_test)

# %%
rf_mae = mean_absolute_error(y_test, rf_predictions)
rf_mse = mean_squared_error(y_test, rf_predictions)

print("Random Forest MAE:", rf_mae)
print("Random Forest MSE:", rf_mse)
# Out:
# Random Forest MAE: 94.33478809142379
# Random Forest MSE: 10325.764505870824

# %%
plt.figure(figsize=(14,7))

plt.plot(y_test.values, label='Actual Price')
plt.plot(rf_predictions, label='Random Forest Prediction')

plt.legend()
plt.title('Random Forest vs Actual')
plt.show()

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.21.0

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in C:\Users\HP\miniconda3\envs\stock-analysis\Lib\site-packages (2.21.0)
# Requirement already satisfied: absl-py>=1.0.0 in C:\Users\HP\miniconda3\envs\stock-analysis\Lib\site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in C:\Users\HP\miniconda3\envs\stock-analysis\Lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=25.9.23 in C:\Users\HP\miniconda3\envs\stock-analysis\Lib\site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in C:\Users\HP\miniconda3\envs\stock-analysis\Lib\site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in C:\Users\HP\miniconda3\envs\stock-analysis\Lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in C:\Users\HP\miniconda3\envs\stock-analysis\Lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in C:\Users\HP\miniconda3\envs\stock-analysis\Lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in C:\Users\HP\miniconda3\envs\stock-analysis\Lib\site-packages (from tensorflow) (26.0)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in C:\Users\HP\miniconda3\envs\stock-analysis\Lib\site-packages (from tensorflow) (7.34.1)
# Requirement already satisfied: requests<3,>=2.21.0 in C:\Users\HP\miniconda3\envs\stock-analysis\Lib\site-packages (from tensorflow) (2.33.1)
# Requirement already satisfied: setuptools in C:\Users\HP\miniconda3\envs\stock-analysis\Lib\site-packages (from tensorflow) (82.0.1)
# Requirement already satisfied: six>=1.12.0 in C:\Users\HP\miniconda3\envs\stock-analysis\Lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in C:\Users\HP\miniconda3\envs\stock-analysis\Lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in C:\Users\HP\miniconda3\envs\stock-analysis\Lib\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in C:\Users\HP\miniconda3\envs\stock-analysis\Lib\site-packages (from tensorflow) (2.1.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in C:\Users\HP\miniconda3\envs\stock-analysis\Lib\site-packages (from tensorflow) (1.80.0)
# Requirement already satisfied: keras>=3.12.0 in C:\Users\HP\miniconda3\envs\stock-analysis\Lib\site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: numpy>=1.26.0 in C:\Users\HP\miniconda3\envs\stock-analysis\Lib\site-packages (from tensorflow) (2.4.4)
# Requirement already satisfied: h5py<3.15.0,>=3.11.0 in C:\Users\HP\miniconda3\envs\stock-analysis\Lib\site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in C:\Users\HP\miniconda3\envs\stock-analysis\Lib\site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\HP\miniconda3\envs\stock-analysis\Lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\HP\miniconda3\envs\stock-analysis\Lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.13)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\HP\miniconda3\envs\stock-analysis\Lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in C:\Users\HP\miniconda3\envs\stock-analysis\Lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2026.4.22)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in C:\Users\HP\miniconda3\envs\stock-analysis\Lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.46.3)
# Requirement already satisfied: rich in C:\Users\HP\miniconda3\envs\stock-analysis\Lib\site-packages (from keras>=3.12.0->tensorflow) (15.0.0)
# Requirement already satisfied: namex in C:\Users\HP\miniconda3\envs\stock-analysis\Lib\site-packages (from keras>=3.12.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in C:\Users\HP\miniconda3\envs\stock-analysis\Lib\site-packages (from keras>=3.12.0->tensorflow) (0.19.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\HP\miniconda3\envs\stock-analysis\Lib\site-packages (from rich->keras>=3.12.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\HP\miniconda3\envs\stock-analysis\Lib\site-packages (from rich->keras>=3.12.0->tensorflow) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\HP\miniconda3\envs\stock-analysis\Lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow) (0.1.2)

# %%
from sklearn.preprocessing import MinMaxScaler
import numpy as np

scaler = MinMaxScaler(feature_range=(0,1))

scaled_data = scaler.fit_transform(icici_df[['Close']])

# %%
X_lstm = []
y_lstm = []

for i in range(60, len(scaled_data)):
    X_lstm.append(scaled_data[i-60:i, 0])
    y_lstm.append(scaled_data[i, 0])

X_lstm = np.array(X_lstm)
y_lstm = np.array(y_lstm)

# %%
X_lstm = np.reshape(
    X_lstm,
    (X_lstm.shape[0], X_lstm.shape[1], 1)
)

# %%
split = int(len(X_lstm) * 0.8)

X_train_lstm = X_lstm[:split]
X_test_lstm = X_lstm[split:]

y_train_lstm = y_lstm[:split]
y_test_lstm = y_lstm[split:]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

model_lstm = Sequential()

model_lstm.add(LSTM(
    units=50,
    return_sequences=True,
    input_shape=(X_train_lstm.shape[1], 1)
))

model_lstm.add(LSTM(
    units=50,
    return_sequences=False
))

model_lstm.add(Dense(units=25))
model_lstm.add(Dense(units=1))
# Out:
# C:\Users\HP\miniconda3\envs\stock-analysis\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model_lstm.compile(
    optimizer='adam',
    loss='mean_squared_error'
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
model_lstm.fit(
    X_train_lstm,
    y_train_lstm,
    batch_size=32,
    epochs=10
)
# Out:
# Epoch 1/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 7s 66ms/step - loss: 0.0430
# Epoch 2/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.0090
# Epoch 3/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 0.0052
# Epoch 4/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 0.0037
# Epoch 5/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0024
# Epoch 6/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 0.0020
# Epoch 7/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0018
# Epoch 8/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0018
# Epoch 9/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0019
# Epoch 10/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - loss: 0.0019

# %%
lstm_predictions = model_lstm.predict(X_test_lstm)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 269ms/step

# %%
lstm_predictions = scaler.inverse_transform(lstm_predictions)

y_test_actual = scaler.inverse_transform(
    y_test_lstm.reshape(-1,1)
)

# %%
from sklearn.metrics import mean_absolute_error

lstm_mae = mean_absolute_error(
    y_test_actual,
    lstm_predictions
)

print("LSTM MAE:", lstm_mae)
# Out:
# LSTM MAE: 25.407708502435064

# %%
plt.figure(figsize=(14,7))

plt.plot(y_test_actual, label='Actual Price')
plt.plot(lstm_predictions, label='LSTM Predicted Price')

plt.legend()
plt.title('LSTM Actual vs Predicted')
plt.show()

# %%
future_input = scaled_data[-60:].reshape(1, 60, 1)

future_predictions = []

for i in range(7):
    pred = model_lstm.predict(future_input)
    future_predictions.append(pred[0,0])

    future_input = np.append(
        future_input[:,1:,:],
        [[[pred[0,0]]]],
        axis=1
    )
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step

# %%
future_predictions = np.array(future_predictions).reshape(-1,1)

future_predictions = scaler.inverse_transform(
    future_predictions
)

print(future_predictions)
# Out:
# [[1306.2948]
#  [1305.7933]
#  [1305.983 ]
#  [1306.5833]
#  [1307.4287]
#  [1308.424 ]
#  [1309.5131]]

# %%
plt.figure(figsize=(12,6))

plt.plot(range(1,8), future_predictions)

plt.title('Next 7-Day ICICI Forecast')
plt.xlabel('Days Ahead')
plt.ylabel('Predicted Price')

plt.show()
